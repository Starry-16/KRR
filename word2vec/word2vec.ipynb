# %%
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence
import pandas as pd
import jieba

# %%
df = pd.read_csv('.\\data\\total.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42869 entries, 0 to 42868
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   42869 non-null  object
# dtypes: object(1)
# memory usage: 335.0+ KB

# %%
with open('.\\data\\data.txt','+w') as f:
    for sentence in df['title']:
        sentence_list = jieba.cut(sentence, cut_all = False)
        word = " ".join(sentence_list)
        f.writelines(word + '\n')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\24749\AppData\Local\Temp\jieba.cache
# Loading model cost 0.685 seconds.
# Prefix dict has been built successfully.

# %%
model = Word2Vec(
    LineSentence(open('./data/txt/data.txt', 'r', encoding='utf8')),
    sg = 0,
    vector_size = 100,
    window = 3,
    min_count = 5,
    workers=8
)
 
# 词向量保存
model.wv.save_word2vec_format('./vector/data.vector', binary=False)
 
# 模型保存
model.save('.\\model\\test.model')

# %%
import gensim

# 1 通过模型加载词向量(recommend)
model = gensim.models.Word2Vec.load('.\\model\\test.model')

dic = model.wv.index_to_key
print(dic)
print(len(dic))
print(model.wv.vectors.shape)
# Out:
# [',', '，', '：', '“', '”', '!', '！', '的', '年', '被', '了', '月', '、', '3', '在', '1', '2022', '将', '发布', '日', '-', '2021', '中国', '2', '和', '疫情', '?', '(', ')', '为', '】', '【', '开展', '工作', '新', '人', '《', '》', '岁', '活动', '与', '一', '4', '新增', '5', '例', '预警', '？', '后', '不', '.', '—', '（', '）', '召开', '万', '个', '确诊', '公司', '已', '12', '是', '亿元', '+', '大', '10', '有', '最新', '中', '％', '美国', '项目', '防控', '公布', '6', '病例', '北京', '正式', '男子', '…', '/', '等', '股份', '8', '亿', '科技', '万元', '又', '全国', '分', '服务', '7', '上', '到', '来', '元', '超', '发展', '曝光', '企业', '年度', '本土', '级', '建设', '网友', '市场', '上海', '举行', '对', '安全', '新冠', '再', '20', '黄色', '基金', '西安', '或', '会议', '集团', '上市', '女子', '元旦', '获', '名', '11', '·', '15', '9', '国家', '气象台', '会', '｜', '[', ']', '全球', '都', '多', '区', '完成', '我', '却', '就', '国际', '数据', '新年', '前', '要', '核酸', '30', '回应', '还', '至', '启动', '向', '他', '同比', '请', '第', '行动', '检测', '举办', '投资', '助力', '增长', '山东', '第一', '时', '创新', '0', '推进', '14', '净值', '计划', '调研', '于', '达', '家', '拟', '汽车', '让', '小', '丨', '蓝色', '天', '也', '起', '宣布', '因', '河南', '风险', '人员', 'C', '近', '遭', '广东', '成功', '出炉', '16', '可', '发现', '成', 'SZ', '你', '关注', '下', '大雾', '下跌', '教育', '及', '累计', '上涨', '17', '管理', '中心', '感染者', '资金', '首次', '俄罗斯', '城市', '产品', '给', '开始', '开启', '即将', '广州', '点', '13', '大风', '合作', '日本', '检查', '今年', '医院', '万股', 'HK', '全面', '31', '实现', '＋', '四川', '名单', '交易', '混合', '吗', '浙江', '今日', '产业', '生产', '18', '亮相', '深圳', '报告', '好', '社区', '发生', '市', '注意', '进行', '突破', '时间', '培训', '无症状', '曾', '问题', '实施', '健康', '情况', '品牌', '解除', '最', '次', 'A', '宣传', '紧急', '时代', '连续', '推出', '预计', '暨', '乌克兰', '部分', '银行', '继续', '组织', '股东', '从', '通报', '首发', '行业', '持续', '迎来', 'SH', '系列', '打造', '50', '称', '仍', '公告', '未来', '曼联', '集中', '平台', '约', '成为', '俄', '最高', '陕西', '消息', '减持', '最大', '青岛', '江苏', '控股', '防疫', '球员', '提升', '学习', '调整', '联合', '小时', '湖人', '成立', '啦', '升级', '文化', '公开', '曝', '参加', '较', '用', '专项', '进入', '均', '重', '直播', '世界', '入选', '送', '经济', '官方', '三', '上线', '技术', '创', '街道', '以', '没', '肺炎', '美', '宁波', '重庆', '保持', '并', '能', '支持', '更', '新能源', '警方', '要求', '19', '新闻', '她', '学校', '地', '未', '乡村', '视频', '镇', '40', '24', '机构', '太', '主题', '詹姆斯', '打', '跨年', '高速', '阳性', '业务', '旅游', '高', '专家', '涨', '保障', '总', '100', '法院', '医疗', '志愿', '主力', '03', '比', '分钟', '智能', '环境', '开工', '地区', '结果', '一个', '无', '出', '苹果', '内', '比赛', '历史', '看', '日起', '证券', '01', '冠军', '现场', '只', '群众', '做', '60', '跌', '通过', '协议', '。', '交警', '数字', '系统', '学生', '价格', '有望', '网络', '站', '官宣', '22', '手机', '荣获', '路', '把', '最佳', '再次', '女儿', '期间', '涨幅', '河北', '指数', '华为', '广西', '隔离', '疫苗', '买', '首个', '消费', '回购', '全', '社会', '韩国', '销售', '国内', '小区', '成都', '精神', '其', '政府', '生活', '杭州', '工程', '号', '很', '取消', '云南', '这', '仅', '去', '贵州', '特斯拉', '金融', '基地', '冬奥', '政策', '申请', '重磅', 'CBA', '有限公司', '获得', '提供', '出现', '老人', '重点', '战略', '总统', '整治', '自己', '辽宁', '儿子', '郑州', '单位', '应急', '妻子', '轨迹', '湖南', '球迷', '21', '全部', '25', '部门', '道路', '一起', '基金净值', '调查', '赛季', '交付', '元旦假期', '融资', '首批', '标准', '气象局', '快讯', '小学', '女', '印度', '原因', '亿美元', '最后', '振兴', '净', '车', '提醒', '但', '两', '游戏', '罚', '强', '地铁', '天津', '球队', '抗疫', '信息', '突然', '学雷锋', '民警', '想', '区域', '突发', '安徽', '山西', '建议', '连胜', '全新', '消防', '管控', '交通', '农村', '28', '孩子', '终于', '运营', '迎', '相关', '砍', '全力', '复出', '部署', '严重', '纪录', 'RCEP', '推动', '子公司', '橙色', '可能', '暂停', '影响', '智慧', '我国', '国', '篮网', '销量', '版', '全市', '回归', '食品', '司机', '正', '发行', '恢复', '生态', '感染', 'III', '吃', '离婚', '领导', '人民币', '省', '已经', 'ETF', '赴', '冬奥会', '没有', '加强', '市民', '接受', '督导', '免费', '员工', '能源', '领域', '一般', '全年', '签约', '英超', '模式', '规划', '央视', '综合', '200', '湖北', '今天', '下降', '异动', '生物', '招聘', '全省', '重要', '一年', '开放', '提前', '股权', '香港', '新高', '说', '芯片', '之', '电影', '走', '落地', '机场', '一线', 'NBA', '谁', '扩大', '冰雪', '保护', '业绩', '仪式', '如何', '股票', '接种', '过', '破', '春运', '记者', '人民', '罗', '公安', '海南', '500', '金', '媒体', '开售', '价值', '23', '台', '执行', '还是', '正在', '铁路', '买入', '集体', '目标', '港股', '大会', '南京', '争议', '救援', '美元', '合计', '图', '更新', '夺冠', '武汉', '火箭', '场', '措施', '文明', '公园', '去年', '收购', '景区', '携手', '物资', '所', '着', '球', '中超', '5G', '试点', '县', '地震', '新疆', '副', '超过', '残 ...
# 13398
# (13398, 100)

# %%
# print(model.wv['提供'])
print(model.wv.most_similar('乌克兰', topn=10))
# Out:
# [('拜登', 0.9789222478866577), ('制裁', 0.9787186980247498), ('总统', 0.9741608500480652), ('可能', 0.9741199612617493), ('美', 0.970684289932251), ('俄', 0.9704423546791077), ('表示', 0.9687258005142212), ('没有', 0.9670432209968567), ('称', 0.9652170538902283), ('拒', 0.9644680619239807)]
